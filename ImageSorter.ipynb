# %% [markdown]
# # Image Sorter
# ###### Voor vragen of suggesties, stuur maar :) Groetjes Cedric

# %% [markdown]
# ## Wat doet de code?

# %% [markdown]
# De code heeft als bedoeling om een map met afbeeldingen te sorteren op chronologische volgorde. Zo heb je soms afbeeldingen van Facebook, van Whatsapp en van een fototoestel, allemaal met andere benamingen en daardoor in een vreemde volgorde gesorteerd... Na een reis kan het tof zijn als je iedereen zijn foto's van verschillende apps/toestellen kan samengooien en een gesorteerde versie terugkrijgt, en dat is exact wat je met deze code kan doen!

# %% [markdown]
# ## Hoe gebruik je de code

# %% [markdown]
# Mijn bedoeling is dat iedereen deze code kan gebruiken, daarom zal ik met een stappenplan jullie begeleiden :) Indien je in volgorde de komende stappen doorloopt, zal je erin slagen om een chronologisch gesorteerde map van afbeeldingen terug te krijgen :)

# %% [markdown]
# ### Stap 1: Code uitvoeren
# Uiteraard zal je de code eerst moeten leren uitvoeren, om een blokje met code te gebruiken, klik je in het blokje en doe je vervolgens "Shift+Enter". Indien je dit doet voor onderstaand blokje code zou je normaal het volgende moeten zien:
# ![image.png](attachment:cb30586d-9f86-4cdf-92af-251ae34d67f0.png)

# %%
try:
    # !pip install Pillow
except:
    pass

from PIL import Image
from PIL.ExifTags import TAGS
import os,sys
print("Code is succesvol uitgevoerd")
# Out:
# Code is succesvol uitgevoerd

# %% [markdown]
# ### Stap 2: Afbeeldingen uploaden naar deze website
# Vervolgens zal de code aan je afbeeldingen moeten kunnen, volg nauwlettend volgend stappen en gebruik exact dezelfde benamingen als mij!
